# %% [markdown]
# <a href="https://colab.research.google.com/github/GiGiUCSM/MMDT_T-PY101_Batch03/blob/main/Theingi_San/exercises/Ex04_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
string = "Theingi San"
intial_counter = 0

while intial_counter < len(string):
  print (string[intial_counter])
  intial_counter += 1
# Out:
# T
# h
# e
# i
# n
# g
# i
#
# S
# a
# n

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
weight_inkg = float (input("Please enter a weight in kg above 0: "))

while weight_inkg < 0 :
  print ("Your entry is invalid, please enter again")
  weight_inkg = float(input("Please enter a weight in kg above 0: "))

weight_inlbs = weight_inkg * 2.20462262
print ("{} kg is equal to {}  lbs".format(weight_inkg,weight_inlbs))
# Out:
# Please enter a weight in kg above 0: -2
# Your entry is invalid, please enter again
# Please enter a weight in kg above 0: -1
# Your entry is invalid, please enter again
# Please enter a weight in kg above 0: 3
# 3.0 kg is equal to 6.613867859999999  lbs

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
total_sum = 0
total_count = 0
count = 0

score = float (input("Enter test score above zero:  " ))

while score > 0:
  total_sum += score
  total_count += 1
  count += int(score>90)
  score = float (input("Enter test score above zero:  " ))

average = total_sum / total_count

print("Total number of A above 90 is : {}".format(count))
print("Average score: {}".format(average))
# Out:
# Enter test score above zero:  100
# Enter test score above zero:  200
# Enter test score above zero:  99
# Enter test score above zero:  0
# Total number of A above 90 is : 3
# Average score: 133.0

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
from warnings import catch_warnings
string = input ("Please enter a string: ")
find_letter = input ("Please enter a letter to search for: ")
found = False

for i, char in enumerate(string):
  if char == find_letter:
    print ("The frist occurence letter of {} is at index {}".format(find_letter,i))
    found = True
    break
  if found == False:
    print ("The letter of {} is not found. ".format(find_letter))
# Out:
# Please enter a string: Theingi
# Please enter a letter to search for: n
# The letter of n is not found.
# The letter of n is not found.
# The letter of n is not found.
# The letter of n is not found.
# The frist occurence letter of n is at index 4

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
list = [1,1,1,1,1,1,0]
found_zero = False

for index, value in enumerate(list):
  if value == 0:
    list[index] = 1
    found_zero = True
    break
if found_zero:
  print ("The final list: ", list)
else:
  print ("There are no zero in the list")
# Out:
# The final list:  [1, 1, 1, 1, 1, 1, 1]
